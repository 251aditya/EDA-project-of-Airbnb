# %% [markdown]
# <a href="https://colab.research.google.com/github/251aditya/EDA-project-of-Airbnb/blob/main/Aditya's_Airbnb_booking_Ananlysis_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Airbnb Booking Analysis

# %% [markdown]
# ##### **Project Type**    -  EDA :- Exploratory Data Analysis
# ##### **Contribution**    - INDIVIDUAL
# ###  **Name - Aditya Kumar**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# ![Airbnb-wordimg.jpg](data:image/jpeg;base64,...)

# %% [markdown]
#  I have conducted an exploratory data analysis (EDA) of Airbnb NYC 2019 data to gain insights into the Airbnb market in New York City.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Github link - https://github.com/251aditya/EDA-project-of-Airbnb

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The problem statement for an Airbnb project could be: "How can we improve the user experience for both hosts and guests on the Airbnb platform, while also addressing concerns about regulation and competition in the short-term rental market?"
#
# Some specific goals that could be addressed in this project include:
#
# Improving the search and booking process for guests, making it easier for them to find and book a suitable property. Enhancing the communication and management tools for hosts, allowing them to more easily manage their listings and interact with guests. Developing strategies for addressing regulatory challenges, in order to maintain compliance and avoid legal issues. Identifying ways to differentiate Airbnb from competitors and maintain its competitive edge in the short-term rental market. Identifying ways to improve the overall guest experience, such as providing more detailed information about properties, providing more flexibility for booking and check-in/check-out times, and offering services.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# * The business objective of analyzing Airbnb NYC 2019 data is to gain insights that can be used to optimize the performance and profitability of Airbnb in the NYC market. By understanding the key drivers of demand, identifying opportunities for expansion, improving the guest and host experience, and optimizing pricing and marketing strategies, Airbnb can improve its competitive position and achieve greater success in this important market.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from datetime import datetime
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Airbnb = pd.read_csv('/content/drive/MyDrive/CSV_File/Airbnb NYC 2019.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
Airbnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
Airbnb.tail()
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print(f"Number of rows in this Aribnb dataset  are :- {Airbnb.shape[0]}")
print(f"Number of columns in this Aribnb dataset are :- {Airbnb.shape[1]}")
# Out:
# Number of rows in this Aribnb dataset  are :- 48895
# Number of columns in this Aribnb dataset are :- 16

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
Airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicate_count = Airbnb.duplicated().sum()
print(f"Number of duplicate Value:- {duplicate_count}")
# Out:
# Number of duplicate Value:- 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
null_data = Airbnb.isnull().sum()
null_data.sort_values(ascending = False)
# Out:
# last_review                       10052
# reviews_per_month                 10052
# host_name                            21
# name                                 16
# id                                    0
# host_id                               0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Visualizing the missing values
null_value = (Airbnb.isnull())
fig = plt.figure(figsize = (25, 10))
#creating heatmap for missing values
sns.heatmap(null_value,cmap = 'cividis')
plt.title("Place of missing value in column")
plt.xlabel('Variables')
plt.ylabel('Observation')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# ###***By basic inspection, a particular property name will have one particular host name hosted by that same individual but a particular host name can have multiple properties in an area. So, host_name is a categorical variable here. Also neighbourhood_group (comprising of Manhattan, Brooklyn, Queens, Bronx, Staten Island) and room_type (private,shared,Entire home/apt) fall into this category.***

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
Airbnb.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# ####UNDERSTANDING THE VARIABLES:--
#
#          ID:-    It's a unique id of the House/apartment.
#          Name:-  Name of the listing House/apartment.
#          Host ID:-  Host ID is the government-approved ID for each individual.
#          Neighborhood groups:-  Neighbourhood groups are the cluster of neighborhoods in the area.
#          Neighborhood:-  Area
#          Latitude:- It shows the latitude point of the site.
#          Longitude:-  It shows the longitude point of the site.
#          Room type:-  There are three types of rooms on Airbnb
#                   >> Entire House/Apartment
#                   >> Private Room
#                   >> Shared Room
#          Price:-  Prices are in terms of dollars($) and the total price of an Airbnb  reservation is based on the cost determined by either the Host or Airbnb Co.
#          Minimum Nights:-  Minimum night is a criteria for booking that guests have to pay to book that House or apartment.
#          Number of reviews:-  counts of review which is submitted by guests.
#          Last review:-  Latest review as per the dataset.
#          Review per month:- Number of reviews per month host got.
#          Calculated host listings count:-  Amount of listing per host.
#          Availibility_365:- It shows the total number of days the listings are available during the year.

# %% [markdown]
# ### Variables Description

# %%
# Dataset Describe
Airbnb.describe(include = 'all')
# Out:
#                   id            name       host_id host_name  \
# count   4.889500e+04           48879  4.889500e+04     48874
# unique           NaN           47905           NaN     11452
# top              NaN  Hillside Hotel           NaN   Michael
# freq             NaN              18           NaN       417
# mean    1.901714e+07             NaN  6.762001e+07       NaN
# std     1.098311e+07             NaN  7.861097e+07       NaN
# min     2.539000e+03             NaN  2.438000e+03       NaN
# 25%     9.471945e+06             NaN  7.822033e+06       NaN
# 50%     1.967728e+07             NaN  3.079382e+07       NaN
# 75%     2.915218e+07             NaN  1.074344e+08       NaN
# max     3.648724e+07             NaN  2.743213e+08       NaN
#
#        neighbourhood_group neighbourhood      latitude     longitude  \
# count                48895         48895  48895.000000  48895.000000
# unique                   5           221           NaN           NaN
# ...

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

#Unique value of Neighbourhood_group;
Airbnb['neighbourhood_group'].value_counts()
# Out:
# neighbourhood_group
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: count, dtype: int64

# %%
#Unique value of room_type:
Airbnb['room_type'].value_counts()
# Out:
# room_type
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: count, dtype: int64

# %%
#Unique value fo neighbourhood:
Airbnb['neighbourhood'].value_counts()
# Out:
# neighbourhood
# Williamsburg          3920
# Bedford-Stuyvesant    3714
# Harlem                2658
# Bushwick              2465
# Upper West Side       1971
#                       ...
# Fort Wadsworth           1
# Richmondtown             1
# New Dorp                 1
# Rossville                1
# Willowbrook              1
# Name: count, Length: 221, dtype: int64

# %%
#Unique value of host name:
Airbnb['host_name'].value_counts()
# Out:
# host_name
# Michael              417
# David                403
# Sonder (NYC)         327
# John                 294
# Alex                 279
#                     ...
# Rhonycs                1
# Brandy-Courtney        1
# Shanthony              1
# Aurore And Jamila      1
# Ilgar & Aysel          1
# Name: count, Length: 11452, dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Filling null values in reviews_per_month column with zero
Airbnb['reviews_per_month'].fillna(0,inplace=True)

# %%
# Filling null values in host_name column with "Unknown"
Airbnb['host_name'].fillna("Unknown",inplace=True)

# %%
# Filling null values in name column with "Unknown"
Airbnb['name'].fillna("Unknown",inplace=True)

# %% [markdown]
# Dropping useless columns

# %%
# Write your code to make your dataset analysis ready.
Airbnb.drop(['latitude', 'longitude', 'last_review'],axis=1,inplace = True)
Airbnb.head(5)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood        room_type  price  \
# 0         John            Brooklyn    Kensington     Private room    149
# 1     Jennifer           Manhattan       Midtown  Entire home/apt    225
# 2    Elisabeth           Manhattan        Harlem     Private room    150
# 3  LisaRoxanne            Brooklyn  Clinton Hill  Entire home/apt     89
# 4        Laura           Manhattan   East Harlem  Entire home/apt     80
#
#    minimum_nights  number_of_reviews  reviews_per_month  \
# 0               1                  9               0.21
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# When I start Analysing Airbnb Dataset, I Saw there is total 48895 Rows  and 16 columns . Inside all the columns we find their are some columns that is  no uses for analysing this data like 'latitude', 'longitude', 'last_review'. So I decided to remove such columns.
#
# After Analysis the Airbnb Data with describe function there are some insights that I found:-
#
#         * The minimum price is zero(0) that is strange.
#
#         * The minimum day in availability is also zero (0) which is also strange.
#
# its mean either data have some missing value or may be data creator not fill all the data properly.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code to find which area having highest listing and by whom :-
hosts_areas = Airbnb.groupby(['host_name','neighbourhood_group'])['calculated_host_listings_count'].max().reset_index()
hosts_areas.sort_values(by='calculated_host_listings_count', ascending=False).head(10)
# Out:
#                host_name neighbourhood_group  calculated_host_listings_count
# 13217       Sonder (NYC)           Manhattan                             327
# 1833          Blueground            Brooklyn                             232
# 1834          Blueground           Manhattan                             232
# 7275                Kara           Manhattan                             121
# 7480              Kazuya              Queens                             103
# 7479              Kazuya           Manhattan                             103
# 7478              Kazuya            Brooklyn                             103
# 6540      Jeremy & Laura           Manhattan                              96
# 13216             Sonder           Manhattan                              96
# 2901   Corporate Housing           Manhattan                              91

# %%
area = hosts_areas['neighbourhood_group']
hostListings = hosts_areas['calculated_host_listings_count']

fig = plt.figure(figsize = (10, 3))

# creating the bar plot
# colors = ['viridis']
plt.bar(area, hostListings , color = 'maroon',
        width = 0.3)

plt.xlabel("Area")
plt.ylabel("Host listing")
plt.title("Area vs Number of listing",color= 'purple')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * I pick this specific chart to identify which area having highest listing and by whom ?

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * As we can see most number of listings are from Manhattan created by Sonder (NYC)and than  Blueground.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * According to this visualization we found that most  number of listings are from Manhattan and than Brooklyn.
#     It means there are less growth in areas like Bronx or Staten Island or we can say may be the price is higher than others areas.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code to know which areas getting higher reviews:-
areas_reviews = Airbnb.groupby(['neighbourhood_group'])['number_of_reviews'].max().reset_index()
areas_reviews
# Out:
#   neighbourhood_group  number_of_reviews
# 0               Bronx                321
# 1            Brooklyn                488
# 2           Manhattan                607
# 3              Queens                629
# 4       Staten Island                333

# %%
area = areas_reviews['neighbourhood_group']
review = areas_reviews['number_of_reviews']

# creating the boxplot
fig = plt.figure(figsize = (15, 8))
sns.boxplot(data=Airbnb , x="neighbourhood_group", y="number_of_reviews");

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * I pick this chart to know which areas getting higher reviews.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * I found Queens is the area got highest number of reviews and then Manhattan	is the second one.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * According to this visualization we found that Queens and Manhattan are the areas gots more reviews compared to others areas. It means there are less demand in areas like Bronx or Staten Island or we can say may be the price is higher than others areas.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code for visualize how many reviews got with respect of price.!
price_review = Airbnb.groupby(['price'])['number_of_reviews'].max().reset_index()
price_review
# Out:
#      price  number_of_reviews
# 0        0                 95
# 1       10                 93
# 2       11                113
# 3       12                  8
# 4       13                  9
# ..     ...                ...
# 669   7703                  0
# 670   8000                  1
# 671   8500                  2
# 672   9999                  6
# 673  10000                  5
#
# [674 rows x 2 columns]

# %%
priceList = price_review['price']
review = price_review['number_of_reviews']

fig = plt.figure(figsize = (10, 5))
# creating the scatter plot.
plt.scatter(priceList,review,color= 'purple')
plt.title('Number of review in term of price')
plt.xlabel("price")
plt.ylabel('Number of Review')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * I pick this specific chart because I want to visualize how many reviews got with respect of price?

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * From above visualization we can say that most number of people like to stay in less price and their reviews are higher in those areas.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * From the above visualization people review more where the price are low so as per business perspective price must be in average so that everyone can afford and people like to use Airbnb sites.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code for visualize which type of rooms are more demanded..!
preferableRoomType = Airbnb.groupby(['room_type'])['minimum_nights'].count().reset_index()
preferableRoomType = preferableRoomType.sort_values(by='minimum_nights').head(10)
preferableRoomType
# Out:
#          room_type  minimum_nights
# 2      Shared room            1160
# 1     Private room           22326
# 0  Entire home/apt           25409

# %%
room_types = preferableRoomType['room_type']
nights = preferableRoomType['minimum_nights']
# creating the pie plot
explode = (0.1,0.1, 0.1) # explode is use for gape between the pie chart
colors = ('red','green', 'purple')
plt.pie(nights, autopct='%.2f%%',colors = colors,labels = room_types ,explode = explode,shadow=True)
plt.title('Traffic area based on minimum nights booked',color = 'brown')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * I picked this chart because I want to visualize which type of rooms are more demanded?

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * We found that most of the people like to stay in Entire /apt 🏛 types which is approx 52 % and then people like private room 🏡 that is 45.66 % .

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# >In this above visualization we observe that most of the people prefered Entire room/Apartment and then Private room because as compared to both of them Entire room / Apartment are less price than private room.
#
# >People don't prefered to stay in shared room even there price are low because people always need privacy.
#
# >from the above insights we can say that we need to develop in Entire room /Apartment type of room so we gain more profit.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code for the top 15 busiest hosts.
busy_hosts = Airbnb.groupby(['host_id', 'host_name','room_type'])['number_of_reviews'].max().reset_index()
busy_hosts = busy_hosts.sort_values (by = 'number_of_reviews',ascending=False).head(15)
busy_hosts
# Out:
#         host_id       host_name        room_type  number_of_reviews
# 24497  47621202            Dona     Private room                629
# 7710    4734398              Jj     Private room                607
# 22225  37312959            Maya     Private room                543
# 4593    2369681           Carol     Private room                540
# 19453  26432133        Danielle     Private room                510
# 13714  12949460             Asa  Entire home/apt                488
# 1976     792159           Wanda     Private room                480
# 5059    2680820           Linda     Private room                474
# 161       42273            Dani  Entire home/apt                467
# 18297  23591164          Angela     Private room                466
# 897      277379           Agnes     Private room                458
# 4504    2321321           Lloyd      Shared room                454
# 4424    2267153            John     Private room                451
# ...

# %%
NameOfHost = busy_hosts['host_name']
Reviews_got = busy_hosts['number_of_reviews']

fig = plt.figure(figsize = (15, 5))
#creating line plot
plt.plot(NameOfHost,Reviews_got,color= 'lightgreen')
plt.xlabel('Host Name')
plt.ylabel('Review')
plt.title('Top 15 Busiest Host in terms of reviews',color='purple')
plt.show()

# %% [markdown]
# * I pick this chart to find the top 15 busiest host in terms of reviews.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * We found that Dona is the one who is most busiest hosts and second is Ji and so on.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * These hosts are busy because there room types listed as Entire home/apt	or private room which are preferred by most number of people and also their reviews are higher.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code to find out the relation between room type,neighbourhood groups and number of reviews
types_of_rooms_in_area = Airbnb.groupby(['neighbourhood_group','room_type'])['number_of_reviews'].sum()
types_of_rooms_in_area = types_of_rooms_in_area.sort_values(ascending=False).reset_index()
types_of_rooms_in_area
# Out:
#    neighbourhood_group        room_type  number_of_reviews
# 0             Brooklyn  Entire home/apt             267128
# 1            Manhattan  Entire home/apt             235147
# 2             Brooklyn     Private room             213653
# 3            Manhattan     Private room             209150
# 4               Queens     Private room              93561
# 5               Queens  Entire home/apt              60644
# 6                Bronx     Private room              16312
# 7                Bronx  Entire home/apt              11627
# 8            Manhattan      Shared room              10272
# 9        Staten Island  Entire home/apt               5857
# 10            Brooklyn      Shared room               5793
# 11       Staten Island     Private room               5670
# 12              Queens      Shared room               2745
# 13               Bronx      Shared room                432
# 14       Staten Island      Shared room                 14

# %%
# creating sns.barplot..

fig = plt.figure(figsize = (15, 5))
sns.barplot(x='neighbourhood_group',y='number_of_reviews',hue='room_type',data=types_of_rooms_in_area);

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * I pick this to find out the relation between room type,neighbourhood groups and number of reviews

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * This Graph shows that most number of reviews are given to entire home/apt and private rooms while comparing with all the three types of room availability.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Number of reviews means number of guests that had been to these places. So we can observe from here that people are preferring entire homes and private rooms more than the sharing rooms in all the areas.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code to top 10 and bottom 10 neighbourhood of Airbnb
top10Neighbourhood = Airbnb['neighbourhood'].value_counts().head(10)
bottom10neighbourhood = Airbnb['neighbourhood'].value_counts().tail(10)
print(top10Neighbourhood)
print(bottom10neighbourhood)
# Out:
# neighbourhood
# Williamsburg          3920
# Bedford-Stuyvesant    3714
# Harlem                2658
# Bushwick              2465
# Upper West Side       1971
# Hell's Kitchen        1958
# East Village          1853
# Upper East Side       1798
# Crown Heights         1564
# Midtown               1545
# Name: count, dtype: int64
# neighbourhood
# Howland Hook       2
# Lighthouse Hill    2
# Silver Lake        2
# West Farms         2
# Woodrow            1
# Fort Wadsworth     1
# Richmondtown       1
# New Dorp           1
# Rossville          1
# Willowbrook        1
# Name: count, dtype: int64

# %%
#creating sns.barplot
plt.figure(figsize = (20,5))

plt.subplot(1,2,1)
palette = sns.color_palette("Blues_r", len(top10Neighbourhood+5))

sns.barplot(y = top10Neighbourhood.keys(),
            x = top10Neighbourhood,
            palette=palette)
plt.title("Top 10 Neighbourhood", fontsize = 15,color= "purple")


#creating sns.barplot
plt.subplot(1,2,2)
# Define a color palette (adjust the number of colors for your needs)
palette = sns.color_palette("Reds", len(bottom10neighbourhood))

sns.barplot( y = bottom10neighbourhood.keys(),
            x =bottom10neighbourhood,palette=palette)
plt.title("Bottom 10 Neighbourhood", fontsize = 15,color = 'purple');

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * I pick this chart to know the top and bottom 10 neighbourhood in Airbnb.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Williamsburg, Bedford - Stuyvesant and Harlem are the three highest Neighbourhood
# * willowbrook, Rossville, New Dorp, Richmondtown, Fort Wadsworth and woodrow are the least of the neighbourhood.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Williamsburg, Bedford-Stuyvesant, Harlem, Bushwick, Upper West Side, Hell's Kitchen, East Village, Upper East Side, Crown Heights, Midtown are the top 10 neighbourhood and Willowbrook, Rossville, New Dorp, Richmondtown, Fort Wadsworth, Wdoorow, West Farms, Silver lake, Lighthouse Hill, Howland Hook are the bottom 10 neighbourhood In Airbnb.

# %% [markdown]
# #### Chart - 8 - Correlation Heatmap

# %%
# Correlation Heatmap visualization
numeric_Airbnb = Airbnb.select_dtypes(include=['number'])
fig = plt.figure(figsize = (15, 5))
sns.heatmap(numeric_Airbnb.corr(),annot=True,cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * I pick this chart to find the correlation of the all the variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * We saw all the correaltion between variables.

# %% [markdown]
# #### Chart - 9 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(Airbnb,diag_kind = 'kde',);

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * I picking this pairplot to see both distribution of single variables and relationships between two variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * I saw the relationships between two variables by this pair plot.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?

# %% [markdown]
# * I suggest the client to kindly reviews all the visualization to make your decision strong
#
# * As per business point of view Hotel business men should see that Entire home/apt and private room is more in demand and the shared room is the least, The popular areas for hotel booking are manhattan and brooklyn and the most popular location for hotel booking is Williamsberg so clients should focus on these areas. The minimum nights to stay at the hotel should be as low as possible and the most popular figure turns out to be one minimum night stay.  The most popular price range for people to book hotel is 0-50 dollars and 50-100 dollars so clients put up the listings of these category more. Clients should also take note of the Geographic analysis of the new york before building new hotels or listinn a new room.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In conclusion, the Airbnb project has been a successful venture for both the company and its users. The platform has revolutionized the way people travel, offering a more affordable and unique way to stay in a city, as well as providing a source of income for hosts. The company has faced challenges, such as regulatory issues and competition from traditional hotels, but has continued to grow and expand globally.
#
# Here some more point :-
# ###1. The people who prefer to stay in Entire home or  Apartment they are going to stay bit longer in that particular Neighbourhood only.
# ###2. The people who prefer to stay in Private room they won't stay longer as compared to Home or Apartment.
# ###3. Most people prefer to pay less price.
# ###4. If there are more number of Reviews for particular Neighbourhood group that means that place is a tourist place.
# ###5. If people are not staying more then one night means they are travellers or may be a businessman/employee to visit particular area for meetings.
#
# ###6. The most popular area for the hotel listing is Manhattan.
# ###7.The most popular location for hotel listing is Williamsberg.
#
# ###8.The most popular price range for hotel booking 0 to 50 dollars.
#
# ###9. Availability of the room can be 365 days.
#
# ###10. The popular figure of Minimum night stays for the hotel is 1 day.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***

# %% [markdown]
# ### **Thank you..!!**
